# %% [markdown]
# # PUC Minas Virtual
#
# ## Métodos de Programação Aplicados ao Mercado Financeiro
#
# Este é o primeiro notebook da nossa disciplina, com operações matemáticas básicas.
#
# Autor: Prof. Leopoldo Grajeda
#
# Data da última atualização: 06/02/2023

# %%
2+2          # Soma de números inteiros
# Out:
# 4

# %%
1594*48756   # Multiplicação
# Out:
# 77717064

# %%
60-75        # Subtração
# Out:
# -15

# %%
15/3         # Divisão de números reais
# Out:
# 5.0

# %%
15//3        # Divisão de números inteiros
# Out:
# 5

# %%
15/6         # Divisão de números reais
# Out:
# 2.5

# %%
15//6        # Divisão de números inteiros
# Out:
# 2

# %%
15%6         # Resto da divisão de números inteiros
# Out:
# 3

# %%
2**3         # Potência
# Out:
# 8

# %%
9**0.5       # Potência com expoente fracionário
# Out:
# 3.0

# %%
(-9)**0.5    # Potência com expoente fracionário e resultado complexo
# Out:
# (1.8369701987210297e-16+3j)
