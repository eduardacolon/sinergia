# %% [markdown]
# # PUC Minas Virtual
#
# ## Métodos de Programação Aplicados ao Mercado Financeiro
#
# Este é o 16º notebook da nossa disciplina, sobre a API FRED.
#
# Autor: Prof. Leopoldo Grajeda
#
# Data da última atualização: 15/04/2023

# %%
# Carregamento das bibliotecas NumPy e Pandas
import numpy as np
import pandas as pd

# %%
# FRED API - economic data resources
import fredapi

# %%
# Inserção da chave de acesso do usuário registrado
MeuAcesso = fredapi.Fred('Chave')

# %%
# Busca da série do PIB da China
PIB_China = MeuAcesso.get_series('MKTGDPCNA646NWDB')

# %%
PIB_China.dropna()
# Out:
# 1960-01-01    5.971647e+10
# 1961-01-01    5.005687e+10
# 1962-01-01    4.720936e+10
# 1963-01-01    5.070680e+10
# 1964-01-01    5.970834e+10
#                   ...
# 2017-01-01    1.231041e+13
# 2018-01-01    1.389482e+13
# 2019-01-01    1.427994e+13
# 2020-01-01    1.468767e+13
# 2021-01-01    1.773406e+13
# Length: 62, dtype: float64
